# %%
import os
import pandas as pd
import numpy as np
from talib import abstract
from matplotlib import pyplot as plt
import mplfinance as mpf

# %matplotlib inline

FILE = "../data/QQQ_5y_raw.csv"

# train in QQQ
input_file = os.path.join(FILE)
df = pd.read_csv(input_file)

print(df.head(10))

plt.figure(figsize=(12,12))
# plot the chart
df.plot(x='Date', y='Close', kind="line", title="QQQ 5y Daily Close", figsize=(12,5))
plt.legend(loc="best")
# Out:
#          Date      Open       High        Low     Close  Adj Close    Volume
# 0  1999-03-10  51.12500  51.156250  50.281250  51.06250  44.600906   5232000
# 1  1999-03-11  51.43750  51.734375  50.312500  51.31250  44.819260   9688600
# 2  1999-03-12  51.12500  51.156250  49.656250  50.06250  43.727436   8743600
# 3  1999-03-15  50.43750  51.562500  49.906250  51.50000  44.983032   6369000
# 4  1999-03-16  51.71875  52.156250  51.156250  51.93750  45.365170   4905800
# 5  1999-03-17  51.93750  52.000000  51.406250  51.56250  45.037632   3965000
# 6  1999-03-18  51.50000  52.593750  51.484375  52.56250  45.911079   4848400
# 7  1999-03-19  53.25000  53.250000  51.187500  51.21875  44.737366   7160400
# 8  1999-03-22  51.43750  51.562500  50.500000  50.59375  44.191463   5024800
# 9  1999-03-23  50.31250  50.500000  48.718750  48.81250  42.635620  10962400
