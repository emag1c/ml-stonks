# %% [markdown]
# ## Import the data

# %%
import os
import pandas as pd

input_file = os.path.join(os.getcwd(), "..", "data", "QQQ.csv")
X = pd.read_csv(input_file)

print(f"Data Tail:\n{X.tail(10)}")
print(f"Data shape: {X.shape}")
print(f"Data info:\n{X.info()}")

# %store X
# Out:
# Data Tail:
#      TARGET  EOM  SMA32_CD  SMA64_CD  MIN_MAX_MID  RESLP32  BB20_CDP  RESLP6  \
# 5210      =  5.0       0.0       9.0          9.0      9.0       0.0     9.0
# 5211      =  5.0       0.0       9.0          9.0      9.0       0.0     9.0
# 5212      =  4.0       0.0       9.0          9.0      9.0       0.0     9.0
# 5213      =  5.0       0.0       9.0          9.0      9.0       0.0     8.0
# 5214      =  5.0       1.0       9.0          9.0      9.0       0.0     9.0
# 5215      =  5.0       2.0       9.0          9.0      9.0       0.0     9.0
# 5216      =  5.0       2.0       9.0          9.0      9.0       2.0     9.0
# 5217      =  4.0       3.0       9.0          9.0      9.0       5.0     9.0
# 5218      =  4.0       3.0       9.0          7.0      7.0       8.0     2.0
# 5219      =  4.0       2.0       9.0          7.0      7.0       8.0     0.0
#
#       RSIV32  SQZ  ...  REGP6+  REGP32+  SMA6+  SMA32+  SMA64+  EOM+  MID+  \
# 5210     5.0    0  ...       0        0      0       0       0     1     0
# 5211     5.0    0  ...       1        0      0       0       0     1     0
# 5212     6.0    0  ...       1        0      0       0       0     0     1
# 5213     5.0    0  ...       0        0      0       0       0     0     0
# 5214     6.0    0  ...       0        0      0       0       0     0     0
# 5215     6.0    0  ...       0        0      0       0       0     0     0
# 5216     6.0    0  ...       0        0      0       0       0     1     0
# 5217     6.0    0  ...       1        1      1       0       0     0     1
# 5218     5.0    0  ...       1        1      0       0       0     1     1
# 5219     5.0    0  ...       0        0      0       0       0     0     0
#
#       HIGH+  LOW+  CLOSE
# 5210      0     0      0
# 5211      0     0      0
# 5212      0     1      1
# 5213      0     0      0
# 5214      0     0      0
# 5215      0     0      0
# 5216      0     0      0
# 5217      1     1      1
# 5218      1     1      0
# 5219      0     0      0
#
# [10 rows x 31 columns]
# Data shape: (5220, 31)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5220 entries, 0 to 5219
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TARGET           5220 non-null   object
#  1   EOM              5220 non-null   float64
#  2   SMA32_CD         5220 non-null   float64
#  3   SMA64_CD         5220 non-null   float64
#  4   MIN_MAX_MID      5220 non-null   float64
#  5   RESLP32          5220 non-null   float64
#  6   BB20_CDP         5220 non-null   float64
#  7   RESLP6           5220 non-null   float64
#  8   RSIV32           5220 non-null   float64
#  9   SQZ              5220 non-null   int64
#  10  REGP6_GTE_MID    5220 non-null   int64
#  11  REGP32_GTE_MID   5220 non-null   int64
#  12  REGP64_GTE_MID   5220 non-null   int64
#  13  SMA6_GTE_SMA32   5220 non-null   int64
#  14  SMA32_GTE_SMA64  5220 non-null   int64
#  15  SMA6_GTE_MID     5220 non-null   int64
#  16  SMA32_GTE_MID    5220 non-null   int64
#  17  SMA64_GTE_MID    5220 non-null   int64
#  18  EMA32_GTE_SMA32  5220 non-null   int64
#  19  HIGH_GTE_BB20U   5220 non-null   int64
#  20  LOW_LTE_BB20L    5220 non-null   int64
#  21  REGP6+           5220 non-null   int64
#  22  REGP32+          5220 non-null   int64
#  23  SMA6+            5220 non-null   int64
#  24  SMA32+           5220 non-null   int64
#  25  SMA64+           5220 non-null   int64
#  26  EOM+             5220 non-null   int64
#  27  MID+             5220 non-null   int64
#  28  HIGH+            5220 non-null   int64
#  29  LOW+             5220 non-null   int64
#  30  CLOSE            5220 non-null   int64
# dtypes: float64(8), int64(22), object(1)
# memory usage: 1.2+ MB
# Data info:
# None
# Stored 'X' (DataFrame)

# %% [markdown]
# ## Run the ml model

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder

SHUFFLER_BUFFER_SIZE = 1024
BATCH_SIZE = 10
WINDOW_SIZE = 100
AUTOTUNE = tf.data.experimental.AUTOTUNE
NUM_COLUMNS = 30
LR = 1e-5 # Keep it small when transfer learning
EPOCHS = 30

def create_overlapping(df, steps=10):
    """
    Create overlapping 3d array with a given pandas dataframe X
    :type df: pd.DataFrame
    :param steps:
    :rtype: np.ndarray
    """
    data = None
    for i in range(steps, len(df)):
        if data is None:
            data = np.array([df.iloc[i-steps:i].values])
        else:
            data = np.append(data, [df.iloc[i-steps:i].values], axis=0)
    return data

def test_train_split(x, percent_in_test = 10):
    """
    Taken from: https://stackoverflow.com/questions/51125266/how-do-i-split-tensorflow-datasets/58452268#58452268
    :type x: tf.data.Dataset
    :rtype: tuple
    """
    def is_test(x, y):
        return x % percent_in_test == 0

    def is_train(x, y):
        return not is_test(x, y)

    recover = lambda x,y: y
    x_test = x.enumerate().filter(is_test).map(recover)
    x_train = x.enumerate().filter(is_train).map(recover)
    return x_test, x_train

def create_dataset(x, labels, is_training=True):
    # create the dataset
    ds = tf.data.Dataset.from_tensor_slices((x, labels))
    if is_training is True:
        ds = ds.cache().shuffle(SHUFFLER_BUFFER_SIZE)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

def split_test_train_dataframe(df):
    """
    :param df:
    :type df: pd.DataFrame
    :return:
    """
    df.dropna(inplace=True)
    labels = pd.get_dummies(df.pop("TARGET")[WINDOW_SIZE:]) # type: pd.DataFrame
    label_names = labels.columns
    # one hot encode the labels
    x_train, x_test, lables_train, labels_test = train_test_split(
        create_overlapping(df, WINDOW_SIZE),
        labels,
        test_size=0.33,
        random_state=False)
    return (create_dataset(x_train, lables_train, True),
            create_dataset(x_test, labels_test,  False), label_names)

def evaluate_model(train_ds, validate_ds, epochs=10):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv1D(128, 3, activation='relu', input_shape=(WINDOW_SIZE, NUM_COLUMNS), name='conv_2'),
        tf.keras.layers.Conv1D(128, 3, activation='relu', name='conv_1'),
        tf.keras.layers.Dropout(0.5, name='dropout_1'),
        tf.keras.layers.MaxPooling1D(pool_size=2, name='pooling_1'),
        tf.keras.layers.Flatten(name='flatten'),
        tf.keras.layers.Dense(100, activation='relu', name='dense_1'),
        tf.keras.layers.Dense(5, activation='softmax', name='output')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
                  loss=tf.keras.losses.categorical_crossentropy,
                  metrics=['accuracy'])
    history = model.fit(train_ds, epochs=epochs, validation_data=validate_ds)
    print(history)
    _, accuracy = model.evaluate(train_ds)
    return accuracy

X_train, X_test, labels = split_test_train_dataframe(X)

print(X_train)
print(X_test)
print(X_train)
print(X_test)
print(labels)
print(X_train)
results = evaluate_model(X_train, X_test, EPOCHS)
print(results)
# Out:
# <PrefetchDataset shapes: ((None, 100, 30), (None, 5)), types: (tf.float64, tf.uint8)>
# <PrefetchDataset shapes: ((None, 100, 30), (None, 5)), types: (tf.float64, tf.uint8)>
# <PrefetchDataset shapes: ((None, 100, 30), (None, 5)), types: (tf.float64, tf.uint8)>
# <PrefetchDataset shapes: ((None, 100, 30), (None, 5)), types: (tf.float64, tf.uint8)>
# Index(['+', '++', '-', '--', '='], dtype='object')
# <PrefetchDataset shapes: ((None, 100, 30), (None, 5)), types: (tf.float64, tf.uint8)>
# Epoch 1/30
# 343/343 [==============================] - 2s 6ms/step - loss: 1.2971 - accuracy: 0.4519 - val_loss: 1.0395 - val_accuracy: 0.4491
# Epoch 2/30
# 343/343 [==============================] - 2s 6ms/step - loss: 1.0935 - accuracy: 0.4904 - val_loss: 0.9850 - val_accuracy: 0.4970
# Epoch 3/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.9993 - accuracy: 0.5230 - val_loss: 0.9670 - val_accuracy: 0.5219
# Epoch 4/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.9851 - accuracy: 0.5152 - val_loss: 0.9604 - val_accuracy: 0.5331
# Epoch 5/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.9639 - accuracy: 0.5289 - val_loss: 0.9431 - val_accuracy: 0.5379
# Epoch 6/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.9214 - accuracy: 0.5624 - val_loss: 0.9321 - val_accuracy: 0.5479
# Epoch 7/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.9020 - accuracy: 0.5723 - val_loss: 0.9200 - val_accuracy: 0.5621
# Epoch 8/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.8825 - accuracy: 0.5813 - val_loss: 0.9127 - val_accuracy: 0.5491
# Epoch 9/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.8700 - accuracy: 0.5945 - val_loss: 0.8919 - val_accuracy: 0.5669
# Epoch 10/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.8412 - accuracy: 0.6134 - val_loss: 0.8800 - val_accuracy: 0.5811
# Epoch 11/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.8182 - accuracy: 0.6230 - val_loss: 0.8611 - val_accuracy: 0.5870
# Epoch 12/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.7968 - accuracy: 0.6327 - val_loss: 0.8502 - val_accuracy: 0.5959
# Epoch 13/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.7860 - accuracy: 0.6341 - val_loss: 0.8407 - val_accuracy: 0.5994
# Epoch 14/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.7622 - accuracy: 0.6554 - val_loss: 0.8326 - val_accuracy: 0.6130
# Epoch 15/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.7296 - accuracy: 0.6741 - val_loss: 0.8170 - val_accuracy: 0.6142
# Epoch 16/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.7182 - accuracy: 0.6776 - val_loss: 0.8029 - val_accuracy: 0.6343
# Epoch 17/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6957 - accuracy: 0.6921 - val_loss: 0.7947 - val_accuracy: 0.6308
# Epoch 18/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6745 - accuracy: 0.7015 - val_loss: 0.7856 - val_accuracy: 0.6296
# Epoch 19/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6592 - accuracy: 0.7067 - val_loss: 0.7745 - val_accuracy: 0.6485
# Epoch 20/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6422 - accuracy: 0.7213 - val_loss: 0.7548 - val_accuracy: 0.6586
# Epoch 21/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6156 - accuracy: 0.7420 - val_loss: 0.7436 - val_accuracy: 0.6763
# Epoch 22/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.6106 - accuracy: 0.7388 - val_loss: 0.7349 - val_accuracy: 0.6840
# Epoch 23/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5910 - accuracy: 0.7475 - val_loss: 0.7235 - val_accuracy: 0.6911
# Epoch 24/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5702 - accuracy: 0.7621 - val_loss: 0.7159 - val_accuracy: 0.6947
# Epoch 25/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5504 - accuracy: 0.7845 - val_loss: 0.7092 - val_accuracy: 0.7000
# Epoch 26/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5390 - accuracy: 0.7840 - val_loss: 0.6984 - val_accuracy: 0.7041
# Epoch 27/30
# 343/343 [==============================] - 2s 6ms/step - loss: 0.5322 - accuracy: 0.7860 - val_loss: 0.6874 - val_accuracy: 0.7195
# Epoch 28/30
# 343/343 [==============================] - 2s 7ms/step - loss: 0.5085 - accuracy: 0.7959 - val_loss: 0.6769 - val_accuracy: 0.7154
# Epoch 29/30
# 343/343 [==============================] - 2s 7ms/step - loss: 0.4892 - accuracy: 0.8099 - val_loss: 0.6673 - val_accuracy: 0.7337
# Epoch 30/30
# 343/343 [==============================] - 2s 7ms/step - loss: 0.4788 - accuracy: 0.8175 - val_loss: 0.6594 - val_accuracy: 0.7254
# <tensorflow.python.keras.callbacks.History object at 0x7f97e36e5490>
# 343/343 [==============================] - 1s 2ms/step - loss: 0.4746 - accuracy: 0.8688
# 0.8688046932220459
